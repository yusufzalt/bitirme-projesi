# %%
import pyodbc

# %%
import tkinter as tk
from tkinter import *
import cv2
import os
from PIL import Image, ImageTk
import numpy as np
import pyodbc
from tkinter import messagebox

# %% [markdown]
# # ic ice window yarin kullanilacakdit Unutma

# %%
window = tk.Tk()
window.title("Project")
window.resizable(0,0)
window.geometry('400x300')

canvas1 = tk.Canvas(window,width=350,height=200,bg='ivory')
canvas1.place(x=0,y=20)

    
def capture_image():
    soru=messagebox.askquestion('uyari','isleme devam etmek isteyormusunuz?')
    if soru=='yes':
        cap = None
        face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
        messagebox.showinfo('bidiri','Islem devam edildi...')
        new_window = tk.Toplevel()
        new_window.title('Capture Image')
        new_window.geometry('600x400+400+200')
        new_window.resizable(0,0)
        ic_canvas1 = tk.Canvas(new_window,width=400,height=300,bg='ivory')
        ic_canvas1.place(x=0,y=0)
        def Update():
            ret,frame = cap.read()
            gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
            faces = face_detector.detectMultiScale(gray, 1.2, 5)
            # count=0
            for (x,y,w,h) in faces:
                cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,0), 2)
                
            img = Image.fromarray(frame)
            imgTk = ImageTk.PhotoImage(image = img)
            label_img = tk.Label(ic_canvas1,image=imgTk)
            label_img.image = imgTk
            label_img.place(x=10,y=10)
            
            label_img.after(20,Update)
            
        cap = cv2.VideoCapture(0)
        width = 380
        height = 280
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, width)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, height)
        Update()
        
        def exit():
            window.destroy()
            cv2.destroyAllWindows()
            cap.release()
            import sys
            sys.exit()
        btn_exit = tk.Button(new_window,text = 'Exit',font = ('Algerian',20),command = exit)
        btn_exit.place(x=500,y=350) 
        
        canvas_img = tk.Canvas(new_window,width=210,height=210 )
        canvas_img.place(x=410,y=5)
        canvas_label = tk.Canvas(new_window,width=200,height=300,bg='red')
        canvas_label.place(x=410,y=220)
        
        def face_match():
            ret,frame = cap.read()
            gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
            faces = face_detector.detectMultiScale(gray, 1.2, 5)
            # count=0
            if faces is():
                messagebox.showinfo('bildiri','Yuz Taninamadi')
                return None
            else:
                
                for (x,y,w,h) in faces:
                    cropped = gray[y:y+h,x:x+w]
                cv2.imwrite('img/face_match.jpg',cropped)
                load = Image.open("img/face_match.jpg")
                photo = ImageTk.PhotoImage(load)

                # Labels can be text or images
                img = Label(canvas_img, image=photo, width=200, height=200)
                img.image = photo

                img.place(x=0, y=5)

                clf = cv2.face.LBPHFaceRecognizer_create()
                clf.read("classifier.xml")

                for (x,y,w,h) in faces:
                    id, pred = clf.predict(gray[y:y+h,x:x+w])
                    #confidence = int(100*(1-pred/300))

                    mydb = pyodbc.connect('Driver={SQL Server};'
                                          'Server=DESKTOP-SH8K28R;'
                                          'Database=db_face_recognition;'
                                          'Trusted_Connection=yes;')
                    mycursor = mydb.cursor()

                    mycursor.execute("select ad,yas,adres from KisiBilgi where id=" + str(id))
                    s = mycursor.fetchall()

                    a1 = tk.Label(canvas_label, text="Name = ", font=("Algerian",10))
                    a1.grid(column = 0, row = 0)

                    b1 = tk.Label(canvas_label, text=s[0][0], font=("Arial",10))
                    b1.grid(column = 1, row = 0)

                    c1 = tk.Label(canvas_label, text="Age = ", font=("Algerian",10))
                    c1.grid(column = 0, row = 1)

                    d1 = tk.Label(canvas_label, text = s[0][1], font=("Arial",10))
                    d1.grid(column = 1, row = 1)

                    e1 = tk.Label(canvas_label, text="Address = ", font=("Algerian", 10))
                    e1.grid(column = 0, row = 2)

                    f1 = tk.Label(canvas_label, text= s[0][2], font=("Arial",10))
                    f1.grid(column = 1, row = 2)

            
            
        resim_karsilastir = tk.Button(new_window,text='Resim Cek',bg='green',font = ('Algerian',20) ,command= face_match)
        resim_karsilastir.place(x=5,y=350)
        new_window.mainloop()
    elif soru == 'no':
        messagebox.showinfo('bildiri','islem dorduruldu !!!!')
    else:
        messagebox.showinfo('bildiri','bir sey olmadi !!!!')
btn_capture_image = tk.Button(canvas1,text='Capture Image',font = ('Algerian',20),command=capture_image)
btn_capture_image.place(x=3,y=150)


    
btn_exit = tk.Button(canvas1,text = 'Exit',font = ('Algerian',20),command = exit)
btn_exit.place(x=250,y=150)

window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-11-71ad49d2166a>", line 72, in face_match
#     load = Image.open("img/face_match.jpg")
#   File "C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py", line 2809, in open
#     fp = builtins.open(filename, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'img/face_match.jpg'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-11-71ad49d2166a>", line 72, in face_match
#     load = Image.open("img/face_match.jpg")
#   File "C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py", line 2809, in open
#     fp = builtins.open(filename, "rb")
# ...

# %%
window = tk.Tk()
window.title("Project")
window.resizable(0,0)

load1 = Image.open("logo.png")
photo1 = ImageTk.PhotoImage(load1)


header = tk.Button(window, image=photo1)
header.place(x=5, y=0)

canvas1 = Canvas(window, width = 500, height=250, bg='ivory')
canvas1.place(x=5, y=130)

l1 = tk.Button(canvas1, text="Name", font=("Algerian",15))
l1.place(x=5, y=5)
t1 = tk.Entry(canvas1, width=50, bd=5)
t1.place(x=150, y=10)

l2 = tk.Button(canvas1, text="Age", font=("Algerian",15))
l2.place(x=5, y=50)
t2 = tk.Entry(canvas1, width=50, bd=5)
t2.place(x=150, y=55)

l3 = tk.Button(canvas1, text="Address", font=("Algerian",15))
l3.place(x=5, y=100)
t3 = tk.Entry(canvas1, width=50, bd=5)
t3.place(x=150, y=105)


b1= tk.Button(canvas1, text="Training", font=("Algerian",20), bg='orange', fg='red')
b1.place(x=10, y=180)

b2= tk.Button(canvas1, text="Generate dataset", font=("Algerian",20), bg='pink', fg='black')
b2.place(x=175, y=180)
load2= Image.open("canvas2.png")
photo2 = ImageTk.PhotoImage(load2)

canvas2 =  Canvas(window, width=500, height=250)
canvas2.place(x=5, y=400)
canvas2.create_image(250,125,image=photo2)

b3 = tk.Button(canvas2, text="Capture the image", font=("Algerian",20), bg="gray", fg="black")
b3.place(x=5, y=50)

b4 = tk.Button(canvas2, text="Predict face from live video", font=("Algerian", 20), bg="cyan", fg="black")
b4.place(x=5, y=150)

load3= Image.open('canvas3.png')
photo3 = ImageTk.PhotoImage(load3)

canvas3 = Canvas(window, width=280, height=530)
canvas3.place(x=515, y=130)
canvas3.create_image(140, 265, image=photo3)

window.geometry("800x680")
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-885489c4fda7> in <module>
#       3 window.resizable(0,0)
#       4
# ----> 5 load1 = Image.open("logo.png")
#       6 photo1 = ImageTk.PhotoImage(load1)
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logo.png'

# %%
window = tk.Tk()
window.title("Project")
window.resizable(0,0)

load1 = Image.open("logo.png")
photo1 = ImageTk.PhotoImage(load1)


header = tk.Button(window, image=photo1)
header.place(x=5, y=0)

canvas1 = Canvas(window, width = 500, height=250, bg='ivory')
canvas1.place(x=5, y=130)

l1 = tk.Button(canvas1, text="Name", font=("Algerian",15))
l1.place(x=5, y=5)
t1 = tk.Entry(canvas1, width=50, bd=5)
t1.place(x=150, y=10)

l2 = tk.Button(canvas1, text="Age", font=("Algerian",15))
l2.place(x=5, y=50)
t2 = tk.Entry(canvas1, width=50, bd=5)
t2.place(x=150, y=55)

l3 = tk.Button(canvas1, text="Address", font=("Algerian",15))
l3.place(x=5, y=100)
t3 = tk.Entry(canvas1, width=50, bd=5)
t3.place(x=150, y=105)

def train_classifier():
    data_dir = "C:/Users/abdul/Desktop/Face_Detected/data"
    path = [os.path.join(data_dir, f) for f in os.listdir(data_dir)]
    
    faces = []
    ids = []
    
    for image in path:
        img = Image.open(image).convert('L')
        imageNp = np.array(img, 'uint8')
        id = int(os.path.split(image)[1].split(".")[1])
        
        faces.append(imageNp)
        ids.append(id)
        
    ids = np.array(ids)
    
    # Train and save classifier
    clf = cv2.face.LBPHFaceRecognizer_create()
    clf.train(faces,ids)
    clf.write("classifier.xml")
    messagebox.showinfo("Result","Model trained completed.....")
    

b1= tk.Button(canvas1, text="Training", font=("Algerian",20), bg='orange', fg='red', command=train_classifier)
b1.place(x=10, y=180)

def generate_dataset():
    if (t1.get()=="" or t2.get()=="" or t3.get()==""):
        messagebox.showinfo("Result","Please provide complete details of the user...")
    else:
        mydb = pyodbc.connect('Driver={SQL Server};'
                              'Server=DESKTOP-SH8K28R;'
                              'Database=db_face_recognition;'
                              'Trusted_Connection=yes;')
        mycursor = mydb.cursor()
        mycursor.execute("SELECT * from KisiBilgi")
        myresult = mycursor.fetchall()
        
        id = 1
        for x in myresult:
            id +=1
        
        sql = '''INSERT INTO KisiBilgi(id,ad,yas,adres)
                VALUES
                (?,?,?,?);'''
        val = (id, t1.get(), t2.get(), t3.get())
        mycursor.execute(sql,val)
        mydb.commit()
        
        soru=messagebox.askquestion('uyari','isleme devam etmek isteyormusunuz?')
        if soru=='yes':
            cap = None
            window.withdraw()
            face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
        
            new_window = tk.Toplevel()
            new_window.title('Capture Image')
            new_window.geometry('600x400+400+200')
            new_window.resizable(0,0)
            ic_canvas1 = tk.Canvas(new_window,width=400,height=300,bg='ivory')
            ic_canvas1.place(x=0,y=0)
            def Update():
                ret,frame = cap.read()
                gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
                faces = face_detector.detectMultiScale(gray, 1.2, 5)
                # count=0
                for (x,y,w,h) in faces:
                    cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,0), 2)

                img = Image.fromarray(frame)
                imgTk = ImageTk.PhotoImage(image = img)
                label_img = tk.Label(ic_canvas1,image=imgTk)
                label_img.image = imgTk
                label_img.place(x=10,y=10)

                label_img.after(20,Update)

            cap = cv2.VideoCapture(0)
            width = 380
            height = 280
            cap.set(cv2.CAP_PROP_FRAME_WIDTH, width)
            cap.set(cv2.CAP_PROP_FRAME_HEIGHT, height)
            Update()

            def exit():        
                new_window.withdraw()
                window.deiconify()
                
            btn_exit = tk.Button(new_window,text = 'Exit',font = ('Algerian',20),command = exit)
            btn_exit.place(x=500,y=350)

            canvas_bilgi = tk.Canvas(new_window,width = 180,height=350 ,bg='ivory')
            canvas_bilgi.place(x=400,y=5)


            def capture_img():

                face_classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
                def face_cropped(img):
                    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
                    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
                    # scaling factor = 1.3
                    # minimum neighbor = 5

                    if faces is ():
                        return None
                    for (x,y,w,h) in faces:
                        cropped_face = img[y:y+h,x:x+w]
                    return cropped_face

                id=1
                img_id = 0

                while True:
                    ret, frame = cap.read()
                    if face_cropped(frame) is not None:
                        img_id+=1
                        face = cv2.resize(face_cropped(frame), (200,200))
                        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
                        file_name_path = "data/"+str(t1.get())+"."+str(id)+"."+str(img_id)+".jpg"
                        cv2.imwrite(file_name_path, face)
                        cv2.putText(face, str(img_id), (50,50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)

                        cv2.imshow("Cropped face", face)

                    if cv2.waitKey(1)==13 or int(img_id)==30: #13 is the ASCII character of Enter
                        break

                cv2.destroyAllWindows()
                messagebox.showinfo("Result","Generating dataset is completed.....")
                canvas_img = tk.Canvas(canvas_bilgi,width=180,height=200)
                canvas_img.place(x=0,y=0)

                resim = Image.open('data/'+str(t1.get())+"."+str(id)+'.1'+'.jpg')
                photo = ImageTk.PhotoImage(resim)

                label_img = tk.Label(canvas_img,image=photo,width=150,height=150)
                label_img.image=photo
                label_img.place(x=0,y=0)
                canvas_bilgi2=tk.Canvas(canvas_bilgi,width=180,height=150)
                canvas_bilgi2.place(x=0,y=200)
                a1 = tk.Label(canvas_bilgi2, text="Name = ", font=("Algerian",10))
                a1.grid(column = 0, row = 0)
                b1 = tk.Label(canvas_bilgi2, text=t1.get(), font=("Arial",10))
                b1.grid(column = 1, row = 0)

                c1 = tk.Label(canvas_bilgi2, text="Age = ", font=("Algerian",10))
                c1.grid(column = 0, row = 1)

                d1 = tk.Label(canvas_bilgi2, text = t2.get(), font=("Arial",10))
                d1.grid(column = 1, row = 1)

                e1 = tk.Label(canvas_bilgi2, text="Address = ", font=("Algerian", 10))
                e1.grid(column = 0, row = 2)
                f1 = tk.Label(canvas_bilgi2, text= t3.get(), font=("Arial",10))
                f1.grid(column = 1, row = 2)

                e1 = tk.Label(canvas_bilgi2, text="Cekilen resim =", font=("Algerian", 10))
                e1.grid(column = 0, row = 3)
                f1 = tk.Label(canvas_bilgi2, text=img_id , font=("Arial",10))
                f1.grid(column = 1, row = 3)
                
                t1.delete(0,'end')
                t2.delete(0,'end')
                t3.delete(0,'end')
            btn_capture_img = tk.Button(new_window,text = 'Capture Image',font = ('Algerian',20),bg='green',fg='white',command=capture_img)
            btn_capture_img.place(x=5,y=350)
            new_window.mainloop()
        
b2= tk.Button(canvas1, text="Generate dataset", font=("Algerian",20), bg='pink', fg='black', command = generate_dataset)
b2.place(x=175, y=180)

load2= Image.open("canvas2.png")
photo2 = ImageTk.PhotoImage(load2)

canvas2 =  Canvas(window, width=500, height=250)
canvas2.place(x=5, y=400)
canvas2.create_image(250,125,image=photo2)

def capture_image():
    
    soru=messagebox.askquestion('uyari','isleme devam etmek isteyormusunuz?')
    if soru=='yes':
        cap = cv2.VideoCapture(0)
        face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
        window.withdraw()
        
        new_window = tk.Toplevel()
        new_window.title('Capture Image')
        new_window.geometry('600x400+400+200')
        new_window.resizable(0,0)
        ic_canvas1 = tk.Canvas(new_window,width=400,height=300,bg='ivory')
        ic_canvas1.place(x=0,y=0)
        def Update():
            ret,frame = cap.read()
            gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
            faces = face_detector.detectMultiScale(gray, 1.2, 5)
            # count=0
            for (x,y,w,h) in faces:
                cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,0), 2)
                
            img = Image.fromarray(frame)
            imgTk = ImageTk.PhotoImage(image = img)
            label_img = tk.Label(ic_canvas1,image=imgTk)
            label_img.image = imgTk
            label_img.place(x=10,y=10)
            
            label_img.after(20,Update)
            
        
        width = 380
        height = 280
        cap.set(cv2.CAP_PROP_FRAME_WIDTH, width)
        cap.set(cv2.CAP_PROP_FRAME_HEIGHT, height)
        Update()
        
        def exit():
            new_window.withdraw()
            cap.release()
            
            window.deiconify()
            
        btn_exit = tk.Button(new_window,text = 'Exit',font = ('Algerian',20),command = exit)
        btn_exit.place(x=500,y=350) 
        
        canvas_img = tk.Canvas(new_window,width=210,height=210 )
        canvas_img.place(x=410,y=5)
        canvas_label = tk.Canvas(new_window,width=200,height=300,bg='ivory')
        canvas_label.place(x=410,y=220)
        
        def face_match():
            ret,frame = cap.read()
            gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
            faces = face_detector.detectMultiScale(gray, 1.2, 5)
            # count=0
            for (x,y,w,h) in faces:
                cropped = gray[y:y+h,x:x+w]
            cv2.imwrite('img/face_match.jpg',cropped)
            load = Image.open("img/face_match.jpg")
            photo = ImageTk.PhotoImage(load)

            # Labels can be text or images
            img = Label(canvas_img, image=photo, width=200, height=200)
            img.image = photo

            img.place(x=0, y=5)
            
            clf = cv2.face.LBPHFaceRecognizer_create()
            clf.read("classifier.xml")

            for (x,y,w,h) in faces:
                id, pred = clf.predict(gray[y:y+h,x:x+w])
                #confidence = int(100*(1-pred/300))

            mydb = pyodbc.connect('Driver={SQL Server};'
                                          'Server=DESKTOP-SH8K28R;'
                                          'Database=db_face_recognition;'
                                          'Trusted_Connection=yes;')
            mycursor = mydb.cursor()

            mycursor.execute("select ad,yas,adres from KisiBilgi where id=" + str(id))
            s = mycursor.fetchall()

            a1 = tk.Label(canvas_label, text="Name = ", font=("Algerian",10))
            a1.grid(column = 0, row = 0)
            b1 = tk.Label(canvas_label, text=s[0][0], font=("Arial",10))
            b1.grid(column = 1, row = 0)

            c1 = tk.Label(canvas_label, text="Age = ", font=("Algerian",10))
            c1.grid(column = 0, row = 1)

            d1 = tk.Label(canvas_label, text = s[0][1], font=("Arial",10))
            d1.grid(column = 1, row = 1)

            e1 = tk.Label(canvas_label, text="Address = ", font=("Algerian", 10))
            e1.grid(column = 0, row = 2)
            f1 = tk.Label(canvas_label, text= s[0][2], font=("Arial",10))
            f1.grid(column = 1, row = 2)

            
            
        resim_karsilastir = tk.Button(new_window,text='Resim Cek',bg='green' ,command= face_match)
        resim_karsilastir.place(x=5,y=350)
        new_window.mainloop()
    
    
b3 = tk.Button(canvas2, text="Capture the image", font=("Algerian",20), bg="gray", fg="black", command=capture_image)
b3.place(x=5, y=20)
def detect_face():
    
    def draw_boundary(img, classifier, scaleFactor, minNeighbors, color, text, clf):
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        features = classifier.detectMultiScale(gray_img, scaleFactor, minNeighbors)

        for (x,y,w,h) in features:
            cv2.rectangle(img, (x,y), (x+w,y+h), color, 2 )

            id, pred = clf.predict(gray_img[y:y+h,x:x+w])
            confidence = int(100*(1-pred/300))
            
            mydb = pyodbc.connect('Driver={SQL Server};'
                              'Server=DESKTOP-SH8K28R;'
                              'Database=db_face_recognition;'
                              'Trusted_Connection=yes;')
            mycursor = mydb.cursor()
            
            mycursor.execute("select ad from KisiBilgi where id=" + str(id))
            s = mycursor.fetchone() #tuple
            
            #s  = str('')+str('').join(str(s)) #string
            #s = "+".join(s)
           # if type(s)==tuple: 
                #s = '+'.join(s)  
            if confidence>70:
                cv2.putText(img, str(s) , (x,y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 1, cv2.LINE_AA)
            else:
                cv2.putText(img, "UNKNOWN", (x,y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255), 1, cv2.LINE_AA)

        return img

    # loading classifier
    faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

    clf = cv2.face.LBPHFaceRecognizer_create()
    clf.read("classifier.xml")

    video_capture = cv2.VideoCapture(0)

    while True:
        ret, img = video_capture.read()
        img = draw_boundary(img, faceCascade, 1.3, 6, (255,255,255), "Face", clf)
        cv2.imshow("face Detection", img)

        if cv2.waitKey(1)==13:
            break
    video_capture.release()
    cv2.destroyAllWindows()
    
b4 = tk.Button(canvas2, text="Predict face from live video", font=("Algerian", 20), bg="cyan", fg="black", command=detect_face)
b4.place(x=5, y=100)

def exit():
    window.destroy()
    cv2.destroyAllWindows()
    import sys
    sys.exit()

b4_exit = tk.Button(canvas2,text = 'Exit',font=("Algerian", 20),bg='yellow',fg='black',command=exit)
b4_exit.place(x=5, y=180)


load3= Image.open('canvas3.png')
photo3 = ImageTk.PhotoImage(load3)

canvas3 = Canvas(window, width=280, height=530)
canvas3.place(x=515, y=120)
canvas3.create_image(140, 265, image=photo3)


window.geometry("800x680")
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\abdul\.conda\envs\tensorflow\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "C:\Users\abdul\.conda\envs\tensorflow\lib\tkinter\__init__.py", line 749, in callit
#     func(*args)
#   File "<ipython-input-9-277dbfedd22d>", line 226, in Update
#     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# cv2.error: OpenCV(4.3.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
def detect_face():
    
    def draw_boundary(img, classifier, scaleFactor, minNeighbors, color, text, clf):
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        features = classifier.detectMultiScale(gray_img, scaleFactor, minNeighbors)

        for (x,y,w,h) in features:
            cv2.rectangle(img, (x,y), (x+w,y+h), color, 2 )

            id, pred = clf.predict(gray_img[y:y+h,x:x+w])
            confidence = int(100*(1-pred/300))
            
            mydb = pyodbc.connect('Driver={SQL Server};'
                              'Server=DESKTOP-SH8K28R;'
                              'Database=db_face_recognition;'
                              'Trusted_Connection=yes;')
            mycursor = mydb.cursor()
            
            mycursor.execute("select ad from KisiBilgi where id=" + str(id))
            s = mycursor.fetchone() #tuple
            
            #s  = str('')+str('').join(str(s)) #string
           # s = "+".join(s)
           # if type(s)==tuple: 
                #s = '+'.join(s)  
            if confidence>70:
                cv2.putText(img, str(s ), (x,y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 1, cv2.LINE_AA)
            else:
                cv2.putText(img, "UNKNOWN", (x,y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255), 1, cv2.LINE_AA)

        return img

    # loading classifier
    faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

    clf = cv2.face.LBPHFaceRecognizer_create()
    clf.read("classifier.xml")

    video_capture = cv2.VideoCapture(0)

    while True:
        ret, img = video_capture.read()
        img = draw_boundary(img, faceCascade, 1.3, 5, (255,255,255), "Face", clf)
        cv2.imshow("face Detection", img)

        if cv2.waitKey(1)==13:
            break
    video_capture.release()
    cv2.destroyAllWindows()
detect_face()

# %%
mydb = pyodbc.connect('Driver={SQL Server};'
                              'Server=DESKTOP-SH8K28R;'
                              'Database=db_face_recognition;'
                              'Trusted_Connection=yes;')
mycursor = mydb.cursor()
            
mycursor.execute("delete from KisiBilgi ")
s = mycursor.fetchone()

for i in s:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-14-b2cd702ff74b> in <module>
#       6
#       7 mycursor.execute("delete from KisiBilgi ")
# ----> 8 s = mycursor.fetchone()
#       9
#      10 for i in s:
#
# ProgrammingError: No results.  Previous SQL was not a query.
